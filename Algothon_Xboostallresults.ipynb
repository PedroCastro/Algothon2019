# %%
bt = get_backtest('5dac35b2cde5c84abfc925fe')
bt.create_full_tear_sheet()
# Out:
# 100% Time:  0:00:02|##########################################################|
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2019-01-04</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2019-10-16</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>9</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>-5.2%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-4.1%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>2.9%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>-1.84</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>-1.04</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.83</td>
#     </tr>
#     <tr>
# ...
